# %% [markdown]
# ### Seaborn

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("titanic-training-data.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df=df.drop(["PassengerId","Name","Ticket","Cabin"],axis=1)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# ### Univariate

# %%
sns.countplot(x="Survived",data=df)
plt.show()

# %%
sns.countplot(x="Embarked",data=df)
plt.show()

# %%
sns.countplot(x="Sex",data=df)
plt.show()

# %%
sns.countplot(x="Pclass",data=df)
plt.show()

# %%
sns.boxplot(x="Age",data=df)
plt.show()

# %%
sns.boxplot(x="SibSp",data=df)
plt.show()

# %%
sns.boxplot(x="Fare",data=df)
plt.show()

# %%
sns.boxplot(x="Parch",data=df)
plt.show()

# %%
plt.hist("Age",data=df)
plt.show()

# %%
plt.hist("SibSp",data=df)
plt.show()

# %%
plt.hist("Fare",data=df)
plt.show()

# %% [markdown]
# ### Bivariate

# %%
sns.countplot(x="Survived",hue="Sex",data=df)
plt.show()

# %%
sns.countplot(x="Survived",hue="Embarked",data=df)
plt.show()

# %%
sns.countplot(x="Survived",hue="Pclass",data=df)
plt.show()

# %%
sns.relplot(x="Age",y="Fare",data=df)
# Out:
# C:\Users\user5\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x="Parch",y="Fare",data=df)
# Out:
# C:\Users\user5\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x="Age",y="Parch",data=df)
# Out:
# C:\Users\user5\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x="Survived",y="Age",data=df)
# Out:
# C:\Users\user5\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x="Embarked",y="Age",data=df)
# Out:
# C:\Users\user5\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x="SibSp",y="Age",data=df)
# Out:
# C:\Users\user5\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.catplot(x="Pclass",y="Age",data=df,kind="swarm")

# %%
sns.catplot(x="Pclass",y="Age",data=df,kind="violin")

# %%
sns.catplot(x="Pclass",y="Age",data=df,kind="boxen")

# %%
sns.catplot(x="Pclass",y="Age",data=df,kind="strip")

# %%
sns.catplot(x="Pclass",y="Age",data=df,kind="box")

# %%
sns.catplot(x="Pclass",y="Age",data=df,kind="bar")

# %%
sns.pairplot(df)

# %% [markdown]
# ### MULTIVARIATE ANALYSIS

# %%
sns.catplot(x="Survived",y="Age",hue="Sex",data=df)

# %%
sns.catplot(x="Survived",y="Age",hue="Fare",data=df)

# %%
sns.catplot(x="Pclass",y="Age",hue="Survived",data=df,kind="violin")

# %%
sns.catplot(x="Pclass",y="Age",hue="Survived",data=df,kind="boxen")

# %%
sns.catplot(x="Pclass",y="Age",hue="Survived",data=df,kind="swarm")

# %%
sns.catplot(x="Pclass",y="Age",hue="Survived",data=df,kind="strip")

# %%
sns.catplot(x="Pclass",y="Age",hue="Survived",data=df,kind="bar")
